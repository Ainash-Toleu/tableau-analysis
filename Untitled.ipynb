# %%
#import dependecies

import pandas as pd

# %%
#give a name to data file

data_one = "Resources/JC-202001-citibike-tripdata.csv"

# %%
#create dataframe

data_one_df = pd.read_csv(data_one)

# %%
#check the data in df

data_one_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1           377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2           288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3           435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4           231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3195            Sip Ave               40.730897
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3211        Newark Ave
# ...

# %%
#checking information about df

data_one_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26020 entries, 0 to 26019
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tripduration             26020 non-null  int64
#  1   starttime                26020 non-null  object
#  2   stoptime                 26020 non-null  object
#  3   start station id         26020 non-null  int64
#  4   start station name       26020 non-null  object
#  5   start station latitude   26020 non-null  float64
#  6   start station longitude  26020 non-null  float64
#  7   end station id           26020 non-null  int64
#  8   end station name         26020 non-null  object
#  9   end station latitude     26020 non-null  float64
#  10  end station longitude    26020 non-null  float64
#  11  bikeid                   26020 non-null  int64
#  12  usertype                 26020 non-null  object
#  13  birth year               26020 non-null  int64
# ...

# %%
#finding rows with NaN

#is_NaN = data_one_df.isnull()
#rows_has_NaN = is_NaN.any(axis = 1)
#rows_with_NaN = data_one_df[rows_has_NaN]
#rows_with_NaN

# %%
#rechecking by dropping NaN's

data_one_df.dropna(how = 'any', inplace = True)

# %%
#rechecking information about df

data_one_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26020 entries, 0 to 26019
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tripduration             26020 non-null  int64
#  1   starttime                26020 non-null  object
#  2   stoptime                 26020 non-null  object
#  3   start station id         26020 non-null  int64
#  4   start station name       26020 non-null  object
#  5   start station latitude   26020 non-null  float64
#  6   start station longitude  26020 non-null  float64
#  7   end station id           26020 non-null  int64
#  8   end station name         26020 non-null  object
#  9   end station latitude     26020 non-null  float64
#  10  end station longitude    26020 non-null  float64
#  11  bikeid                   26020 non-null  int64
#  12  usertype                 26020 non-null  object
#  13  birth year               26020 non-null  int64
# ...

# %%
#download all data

data_two = "Resources/JC-202002-citibike-tripdata.csv"
data_three = "Resources/JC-202003-citibike-tripdata.csv"
data_four = "Resources/JC-202004-citibike-tripdata.csv"
data_five = "Resources/JC-202005-citibike-tripdata.csv"
data_six = "Resources/JC-202006-citibike-tripdata.csv"
data_seven = "Resources/JC-202007-citibike-tripdata.csv"
data_eight = "Resources/JC-202008-citibike-tripdata.csv"
data_nine = "Resources/JC-202009-citibike-tripdata.csv"
data_ten = "Resources/JC-202010-citibike-tripdata.csv"
data_eleven = "Resources/JC-202011-citibike-tripdata.csv"
data_twelve = "Resources/JC-202012-citibike-tripdata.csv"

# %%
#put all data in df

data_two_df = pd.read_csv(data_two)
data_three_df = pd.read_csv(data_three)
data_four_df = pd.read_csv(data_four)
data_five_df = pd.read_csv(data_five)
data_six_df = pd.read_csv(data_six)
data_seven_df = pd.read_csv(data_seven)
data_eight_df = pd.read_csv(data_eight)
data_nine_df = pd.read_csv(data_nine)
data_ten_df = pd.read_csv(data_ten)
data_eleven_df = pd.read_csv(data_eleven)
data_twelve_df = pd.read_csv(data_twelve)

# %%
#finding rows with NaN in all data one by one

#is_NaN = data_twelve_df.isnull()
#rows_has_NaN = is_NaN.any(axis = 1)
#rows_with_NaN = data_twelve_df[rows_has_NaN]
#rows_with_NaN

# %%
#merge all data

merged_df = pd.concat([data_one_df, data_two_df, data_three_df, data_four_df, data_five_df, data_six_df, data_seven_df, data_eight_df, data_nine_df, data_ten_df, data_eleven_df, data_twelve_df], ignore_index=True)

# %%
#check indexes in new df

merged_df
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1                377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2                288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3                435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4                231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
# ...              ...                       ...                       ...
# 336797          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 336798          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 336799          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 336800           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 336801          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#         start station id start station name  start station latitude  \
# ...

# %%
#check for duplicates

merged_df.drop_duplicates(keep='first')
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1                377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2                288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3                435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4                231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
# ...              ...                       ...                       ...
# 336797          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 336798          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 336799          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 336800           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 336801          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#         start station id start station name  start station latitude  \
# ...

# %%
#check for unique values in gender column

merged_df['gender'].unique()
# Out:
# array([2, 1, 0])

# %%
#convert gender column from int to object

merged_df['gender'] = merged_df['gender'].astype(str)

# %%
#rename rows in gender column

merged_df['gender'] = merged_df['gender'].replace({
    "0": "unknown",
    "1": "male",
    "2": "female"
})

# %%
#check types of columns

merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336802 entries, 0 to 336801
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   tripduration             336802 non-null  int64
#  1   starttime                336802 non-null  object
#  2   stoptime                 336802 non-null  object
#  3   start station id         336802 non-null  int64
#  4   start station name       336802 non-null  object
#  5   start station latitude   336802 non-null  float64
#  6   start station longitude  336802 non-null  float64
#  7   end station id           336802 non-null  int64
#  8   end station name         336802 non-null  object
#  9   end station latitude     336802 non-null  float64
#  10  end station longitude    336802 non-null  float64
#  11  bikeid                   336802 non-null  int64
#  12  usertype                 336802 non-null  object
# ...

# %%
#recheck for unique values in gender column

merged_df['gender'].unique()
# Out:
# array(['female', 'male', 'unknown'], dtype=object)

# %%
#change starttime  and stoptime columns from object to datetime

merged_df[["starttime", "stoptime"]] = merged_df[["starttime", "stoptime"]].apply(pd.to_datetime)
